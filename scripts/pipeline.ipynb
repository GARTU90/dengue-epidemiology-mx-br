# %%
import pandas as pd
import numpy as np

# %%
M =  pd.read_csv("../data/mexico/dengue_mexico.csv")

# %%
B = pd.read_csv("../data/csv/dengue_brasil.csv",low_memory=False)
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13553796 entries, 0 to 13553795
# Data columns (total 20 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   SG_UF_NOT     object
#  1   ID_MUNICIP    int64
#  2   ID_UNIDADE    float64
#  3   DT_SIN_PRI    object
#  4   CS_SEXO       object
#  5   CS_GESTANT    float64
#  6   SG_UF         int64
#  7   ID_MN_RESI    float64
#  8   DIABETES      float64
#  9   HEPATOPAT     float64
#  10  RENAL         float64
#  11  HIPERTENSA    float64
#  12  ACIDO_PEPT    float64
#  13  AUTO_IMUNE    float64
#  14  SOROTIPO      float64
#  15  CLASSI_FIN    float64
#  16  ALRM_SANG     float64
#  17  TOMA_MUESTRA  float64
#  18  DEFUNCION     int64
#  19  EDAD          int64
# dtypes: float64(13), int64(4), object(3)
# memory usage: 2.0+ GB

# %%
C2 = """SEXO	CS_SEXO
EDAD_ANOS	EDAD
ENTIDAD_RES	SG_UF
MUNICIPIO_RES	ID_MN_RESI
ENTIDAD_UM_NOTIF	SG_UF_NOT
MUNICIPIO_UM_NOTIF	ID_MUNICIP
INSTITUCION_UM_NOTIF	ID_UNIDADE
FECHA_SIGN_SINTOMAS	DT_SIN_PRI
DIABETES	DIABETES
HIPERTENSION	HIPERTENSA
ENFERMEDAD_ULC_PEPTICA	ACIDO_PEPT
ENFERMEDAD_RENAL	RENAL
INMUNOSUPR	AUTO_IMUNE
CIRROSIS_HEPATICA	HEPATOPAT
EMBARAZO	CS_GESTANT
DEFUNCION	DEFUNCION
RESULTADO_PCR	SOROTIPO
ESTATUS_CASO	CLASSI_FIN
TOMA_MUESTRA	TOMA_MUESTRA
HEMORRAGICOS	ALRM_SANG"""

C = [r.split("\t") for r in C2.strip().split("\n")]
C1 = {key:value for key,value in C}
C2 = {key:value for value,key in C}
C1.values()
# Out:
# dict_values(['CS_SEXO', 'EDAD', 'SG_UF', 'ID_MN_RESI', 'SG_UF_NOT', 'ID_MUNICIP', 'ID_UNIDADE', 'DT_SIN_PRI', 'DIABETES', 'HIPERTENSA', 'ACIDO_PEPT', 'RENAL', 'AUTO_IMUNE', 'HEPATOPAT', 'CS_GESTANT', 'DEFUNCION', 'SOROTIPO', 'CLASSI_FIN', 'TOMA_MUESTRA', 'ALRM_SANG'])

# %%
T = M[C1.keys()].copy()
T.info()

#podemos observar que no hay nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216929 entries, 0 to 1216928
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   SEXO                    1216929 non-null  int64
#  1   EDAD_ANOS               1216929 non-null  int64
#  2   ENTIDAD_RES             1216929 non-null  int64
#  3   MUNICIPIO_RES           1216929 non-null  int64
#  4   ENTIDAD_UM_NOTIF        1216929 non-null  int64
#  5   MUNICIPIO_UM_NOTIF      1216929 non-null  int64
#  6   INSTITUCION_UM_NOTIF    1216929 non-null  int64
#  7   FECHA_SIGN_SINTOMAS     1216929 non-null  object
#  8   DIABETES                1216929 non-null  int64
#  9   HIPERTENSION            1216929 non-null  int64
#  10  ENFERMEDAD_ULC_PEPTICA  1216929 non-null  int64
#  11  ENFERMEDAD_RENAL        1216929 non-null  int64
#  12  INMUNOSUPR              1216929 non-null  int64
#  13  CIRROSIS_HEPATICA       1216929 non-null  int64
# ...

# %%
S = []
I = []
F = []

for c in B.columns:
  t = B[c].dtype
  if t == 'float64':F.append(c)
  elif t == 'object':S.append(c)
  elif t == 'int64':I.append(c)

#print(f"S: {S}\nI: {I}\nF: {F}")

MS = [C2[s] for s in S]
MI = [C2[s] for s in I]
MF = [C2[s] for s in F]
#print(f"MS: {MS}")
#print(f"MI: {MI}")
#print(f"MF: {MF}")

# %%
T[MF] = T[MF].astype("float64")
T[MI] = T[MI].astype("int64")
T[MS] = T[MS].astype("object")

# %%
T["SEXO"]=T["SEXO"].replace({1:"F",2:"M"})
T["DEFUNCION"]=T["DEFUNCION"].replace({2:0})
T["TOMA_MUESTRA"]=T["TOMA_MUESTRA"].replace({4:1.0})

# %%
B["CS_GESTANT"] = B["CS_GESTANT"].replace({1:"1.0",2:"1.0",3:"1.0",4:"2.0",5:"2.0",6:"2.0",9:"2.0",np.nan:"2.0"})

# %%
for c in B.columns:
  #print(c)
  print(B[c].value_counts(dropna=False))
# Out:
# SG_UF_NOT
# 35    4388044
# 31    2458588
# 41    1522334
# 52     895447
# 42     605631
# 29     483726
# 53     473904
# 43     433510
# 33     396599
# 32     324472
# 51     225849
# 50     201201
# 23     183753
# 26     168735
# 24      97262
# 25      88919
# 27      77284
# 22      72113
# 12      71287
# 15      68231
# 17      61802
# 13      50843
# 11      43616
# 21      36140
# 28      21180
# 16      15905
# 14       5046
# sp         97
# pr         23
# go         18
# mg         17
# rs         14
# rj         13
# sc         12
# ba          8
# to          4
# am          4
# pa          4
# mt          4
# df          2
# ce          2
# pi          1
# ac          1
# rn          1
# pe          1
# Name: count, dtype: int64
# ID_MUNICIP
# 355030    771157
# 530010    473906
# 310620    299293
# 350950    217727
# 520870    211974
#            ...
# 430630         1
# 420150         1
# 431308         1
# 431446         1
# 421300         1
# ...

# %%
#correcion de nans y valores que no deberian estar como los 9s


B["TOMA_MUESTRA"] = B["TOMA_MUESTRA"].fillna(0)
B["CS_SEXO"] = B["CS_SEXO"].fillna("I")
B["DIABETES"] = B["DIABETES"].replace({np.nan:0,9.0:0})
B["HEPATOPAT"] = B["HEPATOPAT"].replace({np.nan:0,9.0:0})
B["RENAL"] = B["RENAL"].replace({np.nan:0,9.0:0})
B["HIPERTENSA"] = B["HIPERTENSA"].replace({np.nan:0,9.0:0})
B["ACIDO_PEPT"] = B["ACIDO_PEPT"].replace({np.nan:0,9.0:0})
B["AUTO_IMUNE"] = B["AUTO_IMUNE"].replace({np.nan:0,9.0:0})
B["ALRM_SANG"] = B["ALRM_SANG"].replace({np.nan:0,9.0:0})
B["CLASSI_FIN"] = B["CLASSI_FIN"].replace({np.nan:1})

# %%
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13471647 entries, 0 to 13471646
# Data columns (total 20 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   SG_UF_NOT     object
#  1   ID_MUNICIP    int64
#  2   ID_UNIDADE    float64
#  3   DT_SIN_PRI    object
#  4   CS_SEXO       object
#  5   CS_GESTANT    object
#  6   SG_UF         int64
#  7   ID_MN_RESI    float64
#  8   DIABETES      float64
#  9   HEPATOPAT     float64
#  10  RENAL         float64
#  11  HIPERTENSA    float64
#  12  ACIDO_PEPT    float64
#  13  AUTO_IMUNE    float64
#  14  SOROTIPO      float64
#  15  CLASSI_FIN    float64
#  16  ALRM_SANG     float64
#  17  TOMA_MUESTRA  float64
#  18  DEFUNCION     int64
#  19  EDAD          int64
# dtypes: float64(12), int64(4), object(4)
# memory usage: 2.0+ GB

# %%
T.columns = C1.values()

# %%
T.insert(0,"PAIS","M")
B.insert(0,"PAIS","B")

# %%
N = pd.concat([T,B],ignore_index=True)
N
# Out:
#          PAIS CS_SEXO  EDAD  SG_UF  ID_MN_RESI SG_UF_NOT  ID_MUNICIP  \
# 0           M       M    51     17        30.0        17           6
# 1           M       F    38     17        29.0        17           6
# 2           M       F    38     17        29.0        17           6
# 3           M       F     6     17        12.0        17          31
# 4           M       F    32     31        18.0        31          56
# ...       ...     ...   ...    ...         ...       ...         ...
# 14770720    B       M    30     17    170210.0        17      170210
# 14770721    B       F    30     17    170210.0        17      170210
# 14770722    B       F    32     17    170210.0        17      170210
# 14770723    B       F    41     17    170210.0        17      170210
# 14770724    B       F    18     17    170230.0        17      170230
#
#           ID_UNIDADE  DT_SIN_PRI  DIABETES  ...  ACIDO_PEPT  RENAL  \
# 0               12.0  2020-05-28       1.0  ...         2.0    2.0
# ...

# %%
N.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14688576 entries, 0 to 14688575
# Data columns (total 21 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   PAIS          object
#  1   CS_SEXO       object
#  2   EDAD          int64
#  3   SG_UF         int64
#  4   ID_MN_RESI    float64
#  5   SG_UF_NOT     object
#  6   ID_MUNICIP    int64
#  7   ID_UNIDADE    float64
#  8   DT_SIN_PRI    object
#  9   DIABETES      float64
#  10  HIPERTENSA    float64
#  11  ACIDO_PEPT    float64
#  12  RENAL         float64
#  13  AUTO_IMUNE    float64
#  14  HEPATOPAT     float64
#  15  CS_GESTANT    object
#  16  DEFUNCION     int64
#  17  SOROTIPO      float64
#  18  CLASSI_FIN    float64
#  19  TOMA_MUESTRA  float64
#  20  ALRM_SANG     float64
# dtypes: float64(12), int64(4), object(5)
# memory usage: 2.3+ GB

# %%
for c in N.columns:
  #print(c)
  print(N[c].value_counts(dropna=False))
# Out:
# PAIS
# Brasil    13471647
# Mexico     1216929
# Name: count, dtype: int64
# CS_SEXO
# F      8011530
# M      6659905
# I        17083
# NaN         58
# Name: count, dtype: int64
# EDAD
# 24     286653
# 23     283845
# 25     282071
# 22     279468
# 26     279348
#         ...
# 116         2
# 110         2
# 118         1
# 121         1
# 117         1
# Name: count, Length: 120, dtype: int64
# SG_UF
# 35    4384641
# 31    2525822
# 41    1522563
# 52     905428
# 42     602971
# 29     485393
# 53     461968
# 43     433669
# 33     397205
# 32     324639
# 23     233111
# 51     226172
# 50     201670
# 26     194995
# 12     161238
# 14     152110
# 17     144819
# 25     130963
# 27     125032
# 24     123017
# 30     106485
# 15      84665
# 22      83066
# 21      74795
# 20      71804
# 16      71649
# 11      71109
# 13      59538
# 28      59466
# 18      50428
# 19      49740
# 7       47727
# 6       40264
# 5       29812
# 4       20121
# 3       14438
# ...

# %%
N.to_csv("../data/Dengue_BiNacional.csv",index=False)
